# %%
import pandas as pd
df = pd.read_csv("/home/asus/G_school_lectures/Week_1_Lectures/pandas/data/hospital-costs.csv")

# %%
df.head()
# Out:
#    Year  Facility Id                                Facility Name  \
# 0  2011          324  Adirondack Medical Center-Saranac Lake Site
# 1  2011          324  Adirondack Medical Center-Saranac Lake Site
# 2  2011          324  Adirondack Medical Center-Saranac Lake Site
# 3  2011          324  Adirondack Medical Center-Saranac Lake Site
# 4  2011          324  Adirondack Medical Center-Saranac Lake Site
#
#    APR DRG Code  APR Severity of Illness Code  \
# 0             4                             4
# 1             5                             4
# 2            24                             2
# 3            26                             1
# 4            41                             1
#
#                                  APR DRG Description  \
# 0  Tracheostomy W MV 96+ Hours W Extensive Proced...
# 1  Tracheostomy W MV 96+ Hours W/O Extensive Proc...
# 2                   Extracranial Vascular Procedures
# 3          Other Nervous System & Related Procedures
# ...

# %%
df.groupby(['APR DRG Description'])[['Median Charge','Facility Name']].max()
# Out:
#                                                     Median Charge  \
# APR DRG Description
# Abdominal Pain                                           774848.0
# Acute & Subacute Endocarditis                            675901.0
# Acute Anxiety & Delirium States                          373491.0
# Acute Leukemia                                          1230784.0
# Acute Major Eye Infections                               323897.0
# Acute Myocardial Infarction                              170732.0
# Adjustment Disorders & Neuroses Except Depressi...       400071.0
# Alcohol & Drug Dependence W Rehab Or Rehab/Deto...       467072.0
# Alcohol Abuse & Dependence                               399708.0
# Alcoholic Liver Disease                                  325377.0
# Allergic Reactions                                       360479.0
# Amputation Of Lower Limb Except Toes                     415046.0
# Anal Procedures                                          696252.0
# ...

# %%
# Wyoming County Community Hospital Charges the most of viral Meningitis

# %%
df['Total Charges'] = df['Discharges'] * df['Mean Charge']

# %%
df['Total Costs'] = df['Discharges'] * df['Mean Cost']

# %%
df
# Out:
#         Year  Facility Id                                Facility Name  \
# 0       2011          324  Adirondack Medical Center-Saranac Lake Site
# 1       2011          324  Adirondack Medical Center-Saranac Lake Site
# 2       2011          324  Adirondack Medical Center-Saranac Lake Site
# 3       2011          324  Adirondack Medical Center-Saranac Lake Site
# 4       2011          324  Adirondack Medical Center-Saranac Lake Site
# 5       2011          324  Adirondack Medical Center-Saranac Lake Site
# 6       2011          324  Adirondack Medical Center-Saranac Lake Site
# 7       2011          324  Adirondack Medical Center-Saranac Lake Site
# 8       2011          324  Adirondack Medical Center-Saranac Lake Site
# 9       2011          324  Adirondack Medical Center-Saranac Lake Site
# 10      2011          324  Adirondack Medical Center-Saranac Lake Site
# 11      2011          324  Adirondack Medical Center-Saranac Lake Site
# ...

# %%
df['markup'] = df['Total Charges'] / df['Total Costs']

# %%
df.groupby(['Facility Name'])['markup'].max()
# Out:
# Facility Name
# Adirondack Medical Center-Saranac Lake Site                                4.313411
# Albany Medical Center - South Clinical Campus                              1.967397
# Albany Medical Center Hospital                                             6.470310
# Albany Memorial Hospital                                                   5.054817
# Alice Hyde Medical Center                                                  4.800204
# Arnot Ogden Medical Center                                                 5.834078
# Auburn Community Hospital                                                  8.146928
# Aurelia Osborn Fox Memorial Hospital                                       3.364728
# Bellevue Hospital Center                                                   1.318267
# Benedictine Hospital                                                       5.404564
# Bertrand Chaffee Hospital                                                  3.498571
# ...

# %%
# TLC Health Network Tri-Count Memorial Hospital has the lowest markup at 0.015803
# SUNY Downstate Medical Center at LICH has the highest markup at 20.835590

# %%
# top 10 discharges across hospitals
grouped = df.groupby(['APR DRG Description'])['Discharges'].sum().reset_index()
grouped.sort_values('Discharges', ascending =False).head(10)
# Out:
#                                    APR DRG Description  Discharges
# 175  Neonate Birthwt >2499G, Normal Newborn Or Neon...      632412
# 308                                   Vaginal Delivery      458034
# 37                                   Cesarean Delivery      245265
# 99                                       Heart Failure      173826
# 238                                    Other Pneumonia      162344
# 280               Septicemia & Disseminated Infections      161739
# 42               Chronic Obstructive Pulmonary Disease      146461
# 35        Cellulitis & Other Bacterial Skin Infections      124617
# 25           Cardiac Arrhythmia & Conduction Disorders      121042
# 39                                          Chest Pain      117630

# %%
net = df[['Facility Name', 'Total Charges', 'Total Costs']]

# %%
net.head()
# Out:
#                                  Facility Name  Total Charges  Total Costs
# 0  Adirondack Medical Center-Saranac Lake Site      1083867.0     588240.0
# 1  Adirondack Medical Center-Saranac Lake Site       102190.0      59641.0
# 2  Adirondack Medical Center-Saranac Lake Site        85032.0      41328.0
# 3  Adirondack Medical Center-Saranac Lake Site         8833.0       4259.0
# 4  Adirondack Medical Center-Saranac Lake Site         5264.0       1727.0

# %%
net = net.groupby(['Facility Name'])[['Total Costs', 'Total Charges']].sum()

# %%
net['Net Income'] = net['Total Charges'] - net['Total Costs']

# %%
newdf = df[df["APR DRG Description"] == "Viral Meningitis"]

# %%
newdf.head()
# Out:
#      Year  Facility Id                                Facility Name  \
# 24   2011          324  Adirondack Medical Center-Saranac Lake Site
# 557  2011            1               Albany Medical Center Hospital
# 558  2011            1               Albany Medical Center Hospital
# 559  2011            1               Albany Medical Center Hospital
# 560  2011            1               Albany Medical Center Hospital
#
#      APR DRG Code  APR Severity of Illness Code APR DRG Description  \
# 24             51                             1    Viral Meningitis
# 557            51                             1    Viral Meningitis
# 558            51                             2    Viral Meningitis
# 559            51                             3    Viral Meningitis
# 560            51                             4    Viral Meningitis
#
#     APR Severity of Illness Description APR Medical Surgical Code  \
# 24                                Minor                         M
# ...

# %%
newdf = newdf[["Facility Name", "APR DRG Description","APR Severity of Illness Description","Discharges", "Mean Charge", "Median Charge", "Mean Cost"]]

# %%
# Highest charging hospitals for moderate Viral Meningitis
newdf[newdf['APR Severity of Illness Description'] == 'Moderate'].sort_values('Mean Charge', ascending=False)
# Out:
#                                             Facility Name APR DRG Description  \
# 333528                     Orange Regional Medical Center    Viral Meningitis
# 234825  St Lukes Roosevelt Hospital - St Lukes Hospita...    Viral Meningitis
# 69091   New York Presbyterian Hospital - Downtown Divi...    Viral Meningitis
# 48363                             Lutheran Medical Center    Viral Meningitis
# 260620               Beth Israel Med Center-Kings Hwy Div    Viral Meningitis
# 297109                                  Kingston Hospital    Viral Meningitis
# 306845   Memorial Hospital for Cancer and Allied Diseases    Viral Meningitis
# 170416                                Lenox Hill Hospital    Viral Meningitis
# 133191           Beth Israel Medical Center/Petrie Campus    Viral Meningitis
# 218855                           SJRH - St Johns Division    Viral Meningitis
# 287356                 Good Samaritan Hospital of Suffern    Viral Meningitis
# ...

# %%
# with more than 3 discharges & Moderate Viral Meningitis
newdf[(newdf['Discharges'] > 3) & (newdf['APR Severity of Illness Description'] == 'Moderate')].sort_values('Mean Charge', ascending=True)
# Out:
#                                             Facility Name APR DRG Description  \
# 14426                     Cayuga Medical Center at Ithaca    Viral Meningitis
# 123662           Women And Children's Hospital Of Buffalo    Viral Meningitis
# 55958                  Millard Fillmore Suburban Hospital    Viral Meningitis
# 380884           Women And Children's Hospital Of Buffalo    Viral Meningitis
# 34039                                   Highland Hospital    Viral Meningitis
# 157161                               Glens Falls Hospital    Viral Meningitis
# 179596                                     Mercy Hospital    Viral Meningitis
# 212143                         Rochester General Hospital    Viral Meningitis
# 45156              Lincoln Medical & Mental Health Center    Viral Meningitis
# 360017                  St Josephs Hospital Health Center    Viral Meningitis
# 251671           Women And Children's Hospital Of Buffalo    Viral Meningitis
# ...

# %%
# Find which hospital discharges the most cases of Viral Meningitis for all levels of severity.
#newdf.groupby(['APR Severity of Illness Description'])[['Facility Name','Mean Charge']].min()
df66= newdf[newdf.groupby(['Facility Name'])['Discharges'].sum()]
df66
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-03e0c3e7ac27> in <module>
#       1 # Find which hospital discharges the most cases of Viral Meningitis for all levels of severity.
#       2 #newdf.groupby(['APR Severity of Illness Description'])[['Facility Name','Mean Charge']].min()
# ----> 3 df66= newdf[newdf.groupby(['Facility Name'])['Discharges'].sum()]
#       4 df66
#
# ~/.virtualenvs/gurus/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ...

# %%
newdf.groupby(['APR Severity of Illness Description'])[['Facility Name','Mean Charge']].min()

# %%
newdf[newdf['Discharges'] > 3].groupby(['APR Severity of Illness Description'])sort
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.virtualenvs/gurus/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4380             try:
# -> 4381                 return libindex.get_value_box(s, key)
#    4382             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-f6aa8b018432> in <module>
# ...

# %%
newdf[newdf['Discharges'] > 3]
# Out:
#                                             Facility Name APR DRG Description  \
# 557                        Albany Medical Center Hospital    Viral Meningitis
# 558                        Albany Medical Center Hospital    Viral Meningitis
# 559                        Albany Medical Center Hospital    Viral Meningitis
# 2681                           Arnot Ogden Medical Center    Viral Meningitis
# 4490                             Bellevue Hospital Center    Viral Meningitis
# 4491                             Bellevue Hospital Center    Viral Meningitis
# 6752             Beth Israel Medical Center/Petrie Campus    Viral Meningitis
# 6753             Beth Israel Medical Center/Petrie Campus    Viral Meningitis
# 8289    Bronx-Lebanon Hospital Center - Concourse Divi...    Viral Meningitis
# 8290    Bronx-Lebanon Hospital Center - Concourse Divi...    Viral Meningitis
# 9242                    Brookdale Hospital Medical Center    Viral Meningitis
# ...
