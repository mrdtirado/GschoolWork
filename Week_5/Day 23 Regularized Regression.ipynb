# %% [markdown]
# # Regularization Assignment

# %% [markdown]
# Assignment Notebook
# https://github.com/mrdtirado/regularized-regression
#
# Tips notebook
# https://github.com/gSchool/DSI_Lectures/blob/master/regularized-regression/brandon_ma/afternoon-reg-reg.ipynb

# %% [markdown]
# ## Part 1: Loading The Data

# %%
from glm.glm import GLM
from glm.families import Gaussian
import statsmodels as sm

import scipy.stats as stats

import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
diabetes = datasets.load_diabetes()
X = diabetes.data[:100]
y = diabetes.target[:100]

# %%
print(dir(datasets.load_diabetes()))
# Out:
# ['DESCR', 'data', 'data_filename', 'feature_names', 'target', 'target_filename']

# %%
datasets.load_diabetes().feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# The features represent, age, sex, boddy mass index, average blood pressure, and six blood serum measurements.

# %%
print(stats.describe(y))
# Out:
# DescribeResult(nobs=100, minmax=(37.0, 341.0), mean=133.56, variance=4784.531717171717, skewness=0.7865773250236984, kurtosis=0.06501467680723172)

# %%
print(stats.describe(X))
# Out:
# DescribeResult(nobs=100, minmax=(array([-0.10722563, -0.04464164, -0.08380842, -0.10895673, -0.12678067,
#        -0.10684491, -0.10230705, -0.0763945 , -0.09643322, -0.12948301]), array([0.08529891, 0.05068012, 0.12528712, 0.12515848, 0.10300346,
#        0.10891438, 0.18117906, 0.1081111 , 0.13359898, 0.13561183])), mean=array([-0.00980095, -0.0046065 , -0.01053876, -0.01129397, -0.01132447,
#        -0.01203921,  0.009762  , -0.01399102, -0.0107643 , -0.01275844]), variance=array([0.00247256, 0.00223576, 0.00170626, 0.00210262, 0.00191333,
#        0.00190253, 0.00267675, 0.00190608, 0.00184335, 0.00204477]), skewness=array([-0.08991407,  0.32417636,  0.65168989,  0.51982746,  0.24123127,
#         0.22830534,  0.50007532,  0.77393895,  0.4044185 ,  0.26793012]), kurtosis=array([-1.00543144, -1.89490969,  0.25983526,  0.18874473,  0.20269758,
#         0.22377684,  0.2779407 ,  0.12295291,  0.16590826,  0.55598489]))

# %%
df = pd.DataFrame(data=X, columns=datasets.load_diabetes().feature_names)

# %%
df['Diabetes'] = y

# %%
scatter_matrix(df, alpha=0.2, figsize=(20,20), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd3def468d0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Part 2: Ridge Regression

# %%
X = diabetes.data
y = diabetes.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
ridge = Ridge(alpha=0.5)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
predictions = ridge.predict(X_test)

# %%
def mean_square_error(a,b):
    return
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-3dcc6cefd2bd> in <module>
# ----> 1 ridge.summary()
#
# AttributeError: 'Ridge' object has no attribute 'summary'
