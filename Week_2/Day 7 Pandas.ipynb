# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# Load the data1.tsv into a pandas dataframe. Look at pandas various data loading functions and pick an appropriate one to use. Look at it's keyword arguments, they do some pretty powerful things.

# %%
df = pd.read_csv('/home/asus/dsi-warmups/data/data1.tsv', delimiter = '\t')

# %%
df
# Out:
#       custid sex is.employed  income        marital.stat  health.ins  \
# 0       2068   F         NaN   11300             Married        True
# 1       2073   F         NaN       0             Married        True
# 2       2848   M        True    4500       Never Married       False
# 3       5641   M        True   20000       Never Married       False
# 4       6369   F        True   12000       Never Married        True
# 5       8322   F        True  180000       Never Married        True
# 6       8521   M        True  120000       Never Married        True
# 7      12195   M        True   40000             Married        True
# 8      14989   M         NaN    9400             Married        True
# 9      15917   F        True   24000  Divorced/Separated        True
# 10     16551   F         NaN    7000             Married        True
# 11     17134   M        True  220000             Married        True
# 12     17946   F        True   85000  Divorced/Separated        True
# ...

# %% [markdown]
# Use pandas descriptive statistics functionality to find the quantiles, mean, median, mode, min, and max of the data.

# %%
df.describe()
# Out:
#              custid         income  num.vehicles          age
# count  1.000000e+03    1000.000000    944.000000  1000.000000
# mean   6.984997e+05   53504.771000      1.916314    51.699815
# std    4.135083e+05   65478.065729      1.101618    18.863433
# min    2.068000e+03   -8700.000000      0.000000     0.000000
# 25%    3.456668e+05   14600.000000      1.000000    38.000000
# 50%    6.934030e+05   35000.000000      2.000000    50.000000
# 75%    1.044606e+06   67000.000000      2.000000    64.000000
# max    1.414286e+06  615000.000000      6.000000   146.680197

# %% [markdown]
# How many missing values does each column have? Are there any values that appear to be highly unlikely or impossible in a column?

# %%
df.isnull().sum()
# Out:
# custid            0
# sex               0
# is.employed     328
# income            0
# marital.stat      0
# health.ins        0
# housing.type     56
# recent.move      56
# num.vehicles     56
# age               0
# state.of.res      0
# dtype: int64

# %%
# drop data
dfd = df.dropna()

# %%
# Explore why is.employed has so many nas
df['is.employed'].value_counts()

# %%
# Explore why is.employed has so many nas
df2 = df.fillna('missing')

# %%
df2.groupby(['is.employed','age']).size()
# Out:
# is.employed  age
# False        22.000000      1
#              25.000000      1
#              26.000000      1
#              27.000000      2
#              28.000000      2
#              29.000000      2
#              30.000000      1
#              31.000000      3
#              32.000000      2
#              33.000000      2
#              35.000000      3
#              36.000000      1
#              37.000000      2
#              38.000000      1
#              40.000000      4
#              41.000000      1
#              42.000000      1
#              44.000000      1
#              45.000000      1
#              46.000000      3
#              48.000000      2
#              50.000000      4
#              51.000000      2
#              53.000000      4
#              54.000000      2
#              55.000000      4
#              56.000000      3
#              57.000000      2
#              58.000000      2
#              59.000000      1
# ...

# %%
df2.groupby(['is.employed','income']).size()
# Out:
# is.employed  income
# False        -8700       1
#               0          8
#               1200       1
#               2400       1
#               3030       1
#               3160       1
#               3400       1
#               4000       1
#               4300       1
#               5000       1
#               6000       1
#               6200       1
#               6900       1
#               7190       1
#               8400       1
#               9600       1
#               9700       1
#               11400      1
#               12000      1
#               13000      1
#               16000      1
#               16500      1
#               17000      2
#               17300      1
#               19000      2
#               19200      1
#               20000      1
#               20900      1
#               22000      3
#               22250      1
#               22800      1
#               23800      1
#               24700      1
# ...

# %%
[df[df['income'] > 3000]
# Out:
#       custid sex  is.employed  income        marital.stat  health.ins  \
# 0       2068   F         2068   11300             Married        True
# 2       2848   M         2848    4500       Never Married       False
# 3       5641   M         5641   20000       Never Married       False
# 4       6369   F         6369   12000       Never Married        True
# 5       8322   F         8322  180000       Never Married        True
# 6       8521   M         8521  120000       Never Married        True
# 7      12195   M        12195   40000             Married        True
# 8      14989   M        14989    9400             Married        True
# 9      15917   F        15917   24000  Divorced/Separated        True
# 10     16551   F        16551    7000             Married        True
# 11     17134   M        17134  220000             Married        True
# 12     17946   F        17946   85000  Divorced/Separated        True
# ...

# %%
[df[df2['is.employed'] >3000] df['is.employed'].fillna(value=True)]
# Out:
# [Empty DataFrame
#  Columns: [custid, sex, is.employed, income, marital.stat, health.ins, housing.type, recent.move, num.vehicles, age, state.of.res]
#  Index: []]

# %%
git primer and pandas

# %%
df['is.employed'] = df.fillna(df['income']>3000)

# %%
df
# Out:
#       custid sex is.employed  income        marital.stat  health.ins  \
# 0       2068   F        2068   11300             Married        True
# 1       2073   F        2073       0             Married        True
# 2       2848   M        2848    4500       Never Married       False
# 3       5641   M        5641   20000       Never Married       False
# 4       6369   F        6369   12000       Never Married        True
# 5       8322   F        8322  180000       Never Married        True
# 6       8521   M        8521  120000       Never Married        True
# 7      12195   M       12195   40000             Married        True
# 8      14989   M       14989    9400             Married        True
# 9      15917   F       15917   24000  Divorced/Separated        True
# 10     16551   F       16551    7000             Married        True
# 11     17134   M       17134  220000             Married        True
# 12     17946   F       17946   85000  Divorced/Separated        True
# ...
